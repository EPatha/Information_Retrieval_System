# %%
# Step 1: Import necessary libraries
import pandas as pd
from google.colab import files

# Step 2: Upload the file
uploaded = files.upload()

# Step 3: Load the dataset
# Assuming 'output_catur_black.xlsx' is the file you uploaded
file_path = list(uploaded.keys())[0]  # Gets the name of the uploaded file
data = pd.read_excel(file_path)

# Step 4: Display the first few rows to understand the structure
data.head()
# Out:
#      <input type="file" id="files-abe0c37b-f3c0-4759-b52c-d1ceca973346" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abe0c37b-f3c0-4759-b52c-d1ceca973346">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Step 4: Filter games where the first move by Black is 'e4 c5', 'c4 c5', 'b3 c5', 'Nf3 c5', 'd4 c5', 'g3 c5'
filtered_data = data[data['Moves'].str.startswith(('e4 c5', 'c4 c5', 'b3 c5', 'Nf3 c5', 'd4 c5', 'g3 c5'))]

# Map results to numerical values for win rate calculation
filtered_data['Result'] = filtered_data['Result'].map({'1-0': 0, '0-1': 1, '1/2-1/2': 0.5})
filtered_data.head()
# Out:
# <ipython-input-9-a0a763e8db6c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Result'] = filtered_data['Result'].map({'1-0': 0, '0-1': 1, '1/2-1/2': 0.5})
#               White            Black        Date  Result  \
# 0  Swordoftheword16  O0OO0Q0o0O0OQ0o  2024.10.01     1.0
# 1    bach12345_lfay  O0OO0Q0o0O0OQ0o  2024.10.01     1.0
# 2         BestRamen  O0OO0Q0o0O0OQ0o  2024.10.01     0.0
# 3    RobertFontaine  O0OO0Q0o0O0OQ0o  2024.10.01     0.0
# 4     Nursultan1990  O0OO0Q0o0O0OQ0o  2024.10.01     1.0
#
#                                                Moves
# 0  e4 c5 Nf3 d6 Nc3 Nf6 e5 dxe5 Nxe5 e6 a4 Be7 g3...
# 1  e4 c5 d4 cxd4 c3 d3 Bxd3 Nc6 Nf3 g6 O-O Bg7 Bf...
# ...

# %%
# Step 5: Calculate total games and win rate for each opening move
win_rate = filtered_data.groupby(filtered_data['Moves'].str[:2]).agg(
    total_games=('Result', 'count'),
    win_rate=('Result', 'mean')
).reset_index()

# Rename columns for clarity
win_rate.columns = ['Opening Move', 'Total Games', 'Win Rate']
win_rate
# Out:
#   Opening Move  Total Games  Win Rate
# 0           Nf          254  0.423228
# 1           b3           76  0.480263
# 2           c4           96  0.572917
# 3           d4          728  0.466346
# 4           e4         1142  0.449212
# 5           g3           30  0.600000
